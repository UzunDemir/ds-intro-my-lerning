# %% [markdown]
# # Машинное обучение. Практическая работа

# %% [markdown]
# В этой практической работе четыре обязательные задачи.
#
# Они помогут понять, что вы действительно усвоили материал модуля.
#
#
# Удачи!

# %% [markdown]
# ## Цели практической работы
#
# Научиться:
# - обучать модели, основанные на деревьях решений;
# - научиться оценивать и увеличивать их качество.

# %% [markdown]
# ## Что входит в практическую работу
#
# 1. Загрузите датасет и ознакомьтесь с ним.
# 2. Подготовьте базовую модель дерева решений и измерьте её качество.
# 3. Подготовьте базовую модель случайного леса и измерьте её качество.
# 4. Увеличьте точность модели случайного леса на тестовых данных.
# 5. Проведите анализ влияния признаков на модель.

# %% [markdown]
# ## Что оценивается
#
# * Выполнены все четыре задачи. Для каждой:
#  * в коде нет ручных перечислений, все действия автоматизированы;
#  * результаты вычислений и применённых операций корректны;
#  * ответы на вопросы, где требуется, корректны и обоснованы;
#  * код читабелен: переменным даны осмысленные названия, соблюдены отступы и правила расстановки пробелов; стилизация кода соответствует рекомендациям [PEP 8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html).
#
# * Репозиторий проекта оформлен корректно:
#  * содержит осмысленные коммиты, содержащие конкретные реализованные фичи;
#  * ветки названы согласно назначению;
#  * файлы, не связанные с проектом, не хранятся в репозитории.

# %% [markdown]
# ## Как отправить работу на проверку
#
# Сдайте практическую работу этого модуля через систему контроля версий Git сервиса Skillbox GitLab. После загрузки работы на проверку напишите об этом в личном кабинете своему куратору.

# %% [markdown]
# ## Обязательные задачи

# %% [markdown]
# ### Описание датасета:
# - `id`— идентификатор записи;
# - `is_manufacturer_name`— признак производителя автомобиля;
#
# - `region_*`— регион;
# - `x0_*`— тип топлива;
# - `manufacturer_*`— производитель;
# - `short_model_*`— сокращённая модель автомобиля;
# - `title_status_*`— статус;
# - `transmission_*`— коробка передач;
# - `state_*`— штат;
# - `age_category_*`— возрастная категория автомобиля;
#
# - `std_scaled_odometer`— количество пройденных миль (после стандартизации);
# - `year_std`— год выпуска (после стандартизации);
# - `lat_std`— широта (после стандартизации);
# - `long_std`— долгота (после стандартизации);
# - `odometer/price_std`— отношение стоимости к пробегу автомобиля (после стандартизации);
# - `desc_len_std`— количество символов в тексте объявления о продаже (после стандартизации);
# - `model_in_desc_std`— количество наименований модели автомобиля в тексте объявления о продаже (после стандартизации);
# - `model_len_std`— длина наименования автомобиля (после стандартизации);
# - `model_word_count_std`— количество слов в наименовании автомобиля (после стандартизации);
# - `month_std`— номер месяца размещения объявления о продаже автомобиля (после стандартизации);
# - `dayofweek_std`— день недели размещения объявления о продаже автомобиля (после стандартизации);
# - `diff_years_std`— количество лет между годом производства автомобиля и годом размещения объявления о продаже автомобиля (после стандартизации);
#
# - `price`— стоимость;
# - `price_category`— категория цены.

# %% [markdown]
# 1. Подготовка базовой модели
#
# Обучите простую модель классификации с помощью DecisionTreeClassifier на данных из датасета vehicles_dataset_prepared.csv. Для этого сделайте шаги:
#
# 1. Обучите модель дерева решений с зафиксированным random_state на тренировочной выборке.
# 2. Сделайте предикт на тестовой выборке.
# 3. Замерьте точность на тестовой выборке и выведите матрицу ошибок.
# 4. Удалите фичи с нулевыми весами по feature_importance из тренировочной и тестовой выборок.
# 5. Заново обучите модель и измерьте качество.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('data/vehicles_dataset_prepared.csv')

df_prepared = df.copy()
df_prepared = df_prepared.drop(['price', 'odometer/price_std'], axis=1)

x = df_prepared.drop(['price_category'], axis=1)
y = df_prepared['price_category']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Ваш код здесь 
clf = DecisionTreeClassifier(random_state=42)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
predicted_train = clf.predict(x_train)
predicted_test = clf.predict(x_test)

# %%
print(accuracy_score(y_train, predicted_train))
print(accuracy_score(y_test, predicted_test))
# Out:
# 1.0
# 0.6704781704781705

# %%
confusion_matrix(y_test, predicted_test)
# Out:
# array([[738,  54, 205],
#        [ 46, 688, 219],
#        [198, 229, 509]], dtype=int64)

# %%
# выведем важность фичей для каждой колонки датасета
clf.feature_importances_
# Out:
# array([0.03381229, 0.00041354, 0.00263035, ..., 0.00123605, 0.01337808,
#        0.01336986])

# %%
#  выведем список фич и их важности
f_imp_list = list(zip(x_train.columns, clf.feature_importances_))
len(f_imp_list)
# Out:
# 1460

# %%
# отсортируем по [1], то есть по важности в порядке убывания
f_imp_list.sort(key = lambda x: x[1], reverse=True)
f_imp_list
# Out:
# [('age_category_new', 0.17513190799837455),
#  ('model_len_std', 0.0803194933127084),
#  ('std_scaled_odometer', 0.08016567920455406),
#  ('desc_len_std', 0.0694646534867301),
#  ('year_std', 0.05068921069891506),
#  ('lat_std', 0.04422168234859874),
#  ('long_std', 0.038100653282804695),
#  ('id', 0.03381229358186751),
#  ('x0_diesel', 0.03309796144918516),
#  ('dayofweek_std', 0.01337808260070307),
#  ('diff_years_std', 0.013369860358314781),
#  ('manufacturer_kia', 0.009459613218696275),
#  ('short_model_wrangler', 0.009440932301132961),
#  ('manufacturer_ram', 0.008750927873828838),
#  ('manufacturer_hyundai', 0.006408681921554389),
#  ('short_model_f-150', 0.006324703250549752),
#  ('short_model_silverado', 0.005776937527678851),
#  ('model_word_count_std', 0.005064439619491224),
#  ('manufacturer_chevrolet', 0.00502710498444803),
#  ('manufacturer_volkswagen', 0.0049867819674347625),
#  ('short_model_Scion', 0.004865746378858324),
#  ('manufacturer_mercedes-benz', 0.004590363002455257),
#  ('model_in_desc_std', 0.004529057821190303),
#  ('short_model_tacoma', 0.004000610051082216),
#  ('manufacturer_gmc', 0.0039289118170582876),
#  ('manufacturer_dodge', 0.0037631861223813294),
#  ('manufacturer_ford', 0.003511486633924163),
#  ('manufacturer_rover', 0.0033732823080245),
#  ('short_model_f150', 0.003260460984768243),
#  ('manufacturer_mitsubishi', 0.003068423255049309),
#  ('short_model_jetta', 0.003033046515268008),
#  ('short_model_f-250', 0.0030242049857035136),
#  ('manufacturer_nissan', 0.0030184360028594113),
#  ('short_model_sierra', 0.0029869432117612263),
#  ('short_model_corolla', 0.0029833184613038974),
#  ('manufacturer_bmw', 0.002861828372604685),
#  ('manufacturer_toyota', 0.002823420848698194),
#  ('short_model_mustang', 0.002742611352135941),
#  ('x0_gas', 0.002706039186924432),
#  ('is_ford', 0.0026303482144230833),
#  ('title_status_clean', 0.002566814615221571),
#  ('short_model_spark', 0.0023470404734665658),
#  ('short_model_tundra', 0.002302139966921529),
#  ('short_model_escape', 0.002271560048816379),
#  ('manufacturer_honda', 0.0022713940339383672),
#  ('short_model_focus', 0.00217970186087981),
#  ('short_model_corvette', 0.002174320385591667),
#  ('short_model_cruze', 0.002111967033097875),
#  ('state_tx', 0.0020779519970088546),
#  ('manufacturer_jeep', 0.00205901591618718),
#  ('short_model_fj', 0.002058151529915877),
#  ('manufacturer_chrysler', 0.0020504065965724306),
#  ('short_model_sentra', 0.002021722165178021),
#  ('manufacturer_cadillac', 0.0019934183070800795),
#  ('is_chevrolet', 0.001989529247618743),
#  ('short_model_versa', 0.001954031870606839),
#  ('short_model_trax', 0.0019423181932249557),
#  ('state_il', 0.0019175406606951261),
#  ('state_nc', 0.0018571555759963549),
#  ('region_tucson', 0.0018489777161892096),
#  ('title_status_rebuilt', 0.0018352496808910735),
#  ('short_model_fusion', 0.0018125609764122036),
#  ('short_model_x5', 0.001794466880493075),
#  ('state_ca', 0.0017781301827007757),
#  ('state_nm', 0.0017695617284144694),
#  ('transmission_automatic', 0.0017432960623864993),
#  ('short_model_f250', 0.001736848200555386),
#  ('short_model_4runner', 0.001673806715015767),
#  ('short_model_tahoe', 0.0016511462600054775),
#  ('region_flint', 0.001607278199014056),
#  ('state_ky', 0.0015783305145873187),
#  ('short_model_camry', 0.0015387608958745906),
#  ('short_model_f-350', 0.0015359023566685088),
#  ('region_south florida', 0.0015164465039440769),
#  ('short_model_altima', 0.0014969272053689236),
#  ('short_model_2500', 0.0013999105237312579),
#  ('x0_hybrid', 0.0013858022386644179),
#  ('state_ms', 0.0013767645773511159),
#  ('state_ok', 0.001363339111535955),
#  ('short_model_elantra', 0.00134945441049997),
#  ('short_model_escalade', 0.0013352570171890916),
#  ('transmission_manual', 0.001331421022377084),
#  ('state_mi', 0.001321228873702796),
#  ('state_fl', 0.0013049262151651432),
#  ('state_id', 0.0012781476386525877),
#  ('short_model_g', 0.0012520649400646787),
#  ('month_std', 0.0012360548508386182),
#  ('manufacturer_lexus', 0.0012335252849382285),
#  ('short_model_express', 0.0012185268274345841),
#  ('age_category_average', 0.0012105910599200546),
#  ('state_pa', 0.0011927248892266472),
#  ('region_pittsburgh', 0.0011848084447215934),
#  ('region_detroit metro', 0.0011614361011210107),
#  ('short_model_colorado', 0.0011542168911883126),
#  ('short_model_mdx', 0.0011298198975900904),
#  ('short_model_mazda3', 0.0011245101513994997),
#  ('short_model_other', 0.001120708621526352),
#  ('short_model_explorer', 0.0011177547513807771),
#  ('region_buffalo', 0.0011144704038160227),
#  ('x0_other', 0.0010951141371253873),
#  ('region_dallas / fort worth', 0.0010942305490013152),
#  ('short_model_golf', 0.001085711062153026),
#  ('state_wi', 0.0010728200057940132),
#  ('short_model_avalanche', 0.00107127428469429),
#  ('manufacturer_other', 0.0010627236217500332),
#  ('short_model_malibu', 0.001057789550287255),
#  ('short_model_impala', 0.0010519898973340269),
#  ('short_model_super', 0.0010444120826610917),
#  ('state_nj', 0.0010385874577370504),
#  ('region_raleigh / durham / CH', 0.001035781917532355),
#  ('state_co', 0.0010038745905881026),
#  ('short_model_transit', 0.000999841682841816),
#  ('short_model_rogue', 0.000985358569651506),
#  ('short_model_odyssey', 0.0009741616368055223),
#  ('short_model_pilot', 0.0009655020723288777),
#  ('short_model_regal', 0.0009632488817284888),
#  ('title_status_salvage', 0.0009627287272464389),
#  ('age_category_old', 0.0009506481942930487),
#  ('region_colorado springs', 0.0009227971729758694),
#  ('short_model_land', 0.0009212520626853588),
#  ('region_san antonio', 0.000918679991336571),
#  ('x0_electric', 0.000917593398079482),
#  ('short_model_promaster', 0.0009171318438944543),
#  ('region_little rock', 0.0008879845740374658),
#  ('state_nv', 0.0008677614227175202),
#  ('state_md', 0.000862875278626787),
#  ('region_orlando', 0.0008443858360367349),
#  ('region_lakeland', 0.0008422259732129609),
#  ('short_model_edge', 0.0008421733176567865),
#  ('region_minneapolis / st paul', 0.0008397098725172977),
#  ('short_model_f650', 0.0008395216748567143),
#  ('region_stockton', 0.0008366992138363756),
#  ('region_lansing', 0.0008345862811030383),
#  ('short_model_yukon', 0.0008313474821633877),
#  ('short_model_sonic', 0.0008282077690209493),
#  ('region_santa fe / taos', 0.0008269279625024623),
#  ('short_model_500', 0.0008269082904487317),
#  ('short_model_fit', 0.0008208806639927708),
#  ('short_model_camaro', 0.000817132086039178),
#  ('short_model_impreza', 0.0008158568582890448),
#  ('region_bakersfield', 0.0008123928679595645),
#  ('region_san diego', 0.0008118274790679323),
#  ('state_mt', 0.0008085418365485549),
#  ("region_spokane / coeur d'alene", 0.0008065432939177831),
#  ('short_model_gx', 0.0008061389173251743),
#  ('short_model_prius', 0.0008049196070766741),
#  ('region_cincinnati', 0.000800990743131844),
#  ('short_model_sorento', 0.0008001368463503463),
#  ('region_modesto', 0.0007942966599029279),
#  ('short_model_taurus', 0.0007905926622278163),
#  ('region_omaha / council bluffs', 0.0007903582366610144),
#  ('region_fredericksburg', 0.0007797624162363021),
#  ('region_portland', 0.0007792640345983244),
#  ('state_in', 0.0007728159224352377),
#  ('short_model_200', 0.0007724016578631024),
#  ('state_nh', 0.0007649747188451878),
#  ('short_model_titan', 0.0007633673962219027),
#  ('state_oh', 0.0007598564470879744),
#  ('title_status_lien', 0.0007588370259179314),
#  ('short_model_mkz', 0.0007546646636607672),
#  ('region_yakima', 0.0007534746255030681),
#  ('is_toyota', 0.0007528215459067816),
#  ('transmission_other', 0.0007469378669445374),
#  ('manufacturer_volvo', 0.0007462201625148059),
#  ('manufacturer_acura', 0.0007388594101201043),
#  ('short_model_1500', 0.0007374811437909027),
#  ('region_madison', 0.000736830528882564),
#  ('short_model_e-350', 0.0007225846838175726),
#  ('short_model_civic', 0.0007180813803998341),
#  ('short_model_s-class', 0.0007134102056795693),
#  ('manufacturer_mini', 0.00071242982069972),
#  ('short_model_f350', 0.0007108641631432398),
#  ('short_model_qx50', 0.0007025204643131642),
#  ('region_kansas city, MO', 0.0006967720224425806),
#  ('short_model_grand', 0.000691639811770405),
#  ('state_mn', 0.0006851809106479329),
#  ('state_ne', 0.0006767843104227008),
#  ('short_model_cooper', 0.0006747003448139159),
#  ('manufacturer_buick', 0.0006705358875905265),
#  ('short_model_a4', 0.0006675757185816802),
#  ('state_ny', 0.0006663025290357533),
#  ('region_reno / tahoe', 0.0006636210188850514),
#  ('region_santa barbara', 0.0006630713282941928),
#  ('short_model_z4', 0.0006581410575874954),
#  ('state_ia', 0.0006320829847673606),
#  ('region_charlottesville', 0.0006312898165227277),
#  ('short_model_330xi', 0.0006237978728096296),
#  ('short_model_rx', 0.0006236423593306995),
#  ('state_va', 0.0006147686664624694),
#  ('short_model_f-250sd', 0.0006139008617778533),
#  ('state_de', 0.0006117167827102287),
#  ('region_wenatchee', 0.0006006585935467865),
#  ('region_corvallis/albany', 0.0005941551214331556),
#  ('region_memphis', 0.0005853778298665298),
#  ('region_denver', 0.0005821984394228907),
#  ('region_yuba-sutter', 0.0005793012433973268),
#  ('short_model_enclave', 0.0005387777859895651),
#  ('short_model_hummer', 0.0005345375202333475),
#  ('region_fresno / madera', 0.000529378811201721),
#  ('region_kalispell', 0.0005088360868338658),
#  ('short_model_nv2500', 0.0005038892472154262),
#  ('region_charlotte', 0.0004918335011892987),
#  ('manufacturer_mazda', 0.0004898226192484816),
#  ('region_redding', 0.00048118705843738693),
#  ('region_central NJ', 0.0004659140442543022),
#  ('short_model_tiguan', 0.0004426941617108259),
#  ('short_model_santa', 0.0004409256427477635),
#  ('region_saginaw-midland-baycity', 0.00044071945820591186),
#  ('region_nashville', 0.00043720848558288756),
#  ('short_model_sienna', 0.00043500642819213153),
#  ('region_la crosse', 0.00043422311455313376),
#  ('short_model_sprinter', 0.0004341902810473056),
#  ('short_model_gto', 0.0004340001090920387),
#  ('short_model_328xi', 0.00043323810937834277),
#  ('region_lawrence', 0.00043308243778379565),
#  ('short_model_g37', 0.0004329252529728256),
#  ('region_visalia-tulare', 0.00043253345502062906),
#  ('region_birmingham', 0.00043211281558774926),
#  ('region_southern illinois', 0.0004305718520500226),
#  ('region_long island', 0.0004299511167597697),
#  ('region_corpus christi', 0.00042947927462233087),
#  ('short_model_genesis', 0.000429380394892976),
#  ('short_model_m35s', 0.000429380394892976),
#  ('short_model_eurovan', 0.00042862356312672027),
#  ('short_model_e-golf', 0.0004282163772991726),
#  ('region_toledo', 0.0004277916874318719),
#  ('region_grand rapids', 0.0004270489935300808),
#  ('state_ma', 0.0004262417175498726),
#  ('region_bloomington-normal', 0.0004260362291185472),
#  ('region_olympic peninsula', 0.0004250287121910086),
#  ('region_winston-salem', 0.00042501775729442826),
#  ('short_model_tribeca', 0.00042439651530939694),
#  ('short_model_yaris', 0.00042343187014034833),
#  ('short_model_bus', 0.0004228378425405411),
#  ('short_model_renegade', 0.0004224297577509091),
#  ('short_model_k900', 0.0004221628494393476),
#  ('region_akron / canton', 0.0004221628494393476),
#  ('region_ft myers / SW florida', 0.0004221628494393476),
#  ('short_model_lx450', 0.0004221152305537346),
#  ('state_me', 0.00042185484269102605),
#  ('short_model_is', 0.00042177644426430954),
#  ('short_model_cr-v', 0.0004208598776818186),
#  ('short_model_mkx', 0.00042064697289007357),
#  ('short_model_qx80', 0.00041909892174997546),
#  ('region_wilmington', 0.0004190612448312211),
#  ('short_model_excursion', 0.00041871297570735466),
#  ('region_chicago', 0.0004186190070747376),
#  ('region_SF bay area', 0.00041798751346661193),
#  ('short_model_325is', 0.00041789407824819897),
#  ('region_erie', 0.00041776531975768757),
#  ('region_orange county', 0.000415908585003209),
#  ('state_la', 0.000415908585003209),
#  ('short_model_i3', 0.0004150991938894321),
#  ('short_model_sportage', 0.000414208498815223),
#  ('is_audi', 0.00041353695741765627),
#  ('short_model_CLICK', 0.00041317410725081634),
#  ('short_model_xc90', 0.00041289091314418105),
#  ('region_missoula', 0.00041208435266745455),
#  ('short_model_avenger', 0.00041133816099218445),
#  ('short_model_sedona', 0.00041133816099218445),
#  ('manufacturer_subaru', 0.00041133816099218445),
#  ('short_model_cts', 0.00041075304269774343),
#  ('state_ak', 0.00041075304269774343),
#  ('region_inland empire', 0.0004101360623445587),
#  ('region_eastern panhandle', 0.0004090568822259242),
#  ('short_model_rav4', 0.0004088353097480525),
#  ('region_palm springs', 0.0004086235064132009),
#  ('region_south dakota', 0.0004084816459852944),
#  ('region_tuscaloosa', 0.00040795780232415636),
#  ('short_model_avalon', 0.0004077951222105291),
#  ('short_model_cx-5', 0.00040751291480904396),
#  ('state_sd', 0.0004060703021483091),
#  ('region_texarkana', 0.0004057059213018322),
#  ('short_model_Plymouth', 0.00040510576461351514),
#  ('region_danville', 0.00040510576461351514),
#  ('manufacturer_porsche', 0.00040477029724704543),
#  ('short_model_forte', 0.0004047006588489009),
#  ('region_tri-cities', 0.00040254475115906243),
#  ('short_model_m3', 0.00040156690965827125),
#  ('region_boise', 0.00040105470696738017),
#  ('region_indianapolis', 0.00040105470696738017),
#  ('region_youngstown', 0.0004009732201756485),
#  ('region_st cloud', 0.0004004166880450358),
#  ('short_model_e450', 0.000399432014408844),
#  ('short_model_plymouth', 0.000399432014408844),
#  ('region_abilene', 0.0003986425387393401),
#  ('short_model_e350', 0.0003977238373472235),
#  ('short_model_dart', 0.00039668678441625096),
#  ('region_tallahassee', 0.0003961034142887703),
#  ('manufacturer_jaguar', 0.0003961034142887703),
#  ('short_model_e', 0.00039577767134938715),
#  ('region_greenville / upstate', 0.000394884634552497),
#  ('region_worcester / central MA', 0.000394884634552497),
#  ('region_philadelphia', 0.0003912164241124804),
#  ('region_columbus', 0.00039017193971078843),
#  ('short_model_frontier', 0.0003901428977946837),
#  ('region_vermont', 0.00038991429844050836),
#  ('manufacturer_audi', 0.00038991429844050836),
#  ('region_baltimore', 0.0003896058707404285),
#  ('region_des moines', 0.0003893431906896446),
#  ('short_model_a8', 0.00038832281150809794),
#  ('short_model_traverse', 0.0003882503682906917),
#  ('short_model_428', 0.0003876173069916692),
#  ('region_albuquerque', 0.0003859355811094837),
#  ('region_sarasota-bradenton', 0.00038346458824074076),
#  ('region_rochester', 0.0003819568637784572),
#  ('region_maine', 0.00038117409554653164),
#  ('short_model_verano', 0.0003792433044816494),
#  ('short_model_mirage', 0.00037678129651858613),
#  ('short_model_z3', 0.0003765588379258374),
#  ('short_model_passat', 0.0003744427563236501),
#  ('region_western massachusetts', 0.00037391477555617065),
#  ('short_model_isf', 0.0003718125897056239),
#  ('region_wichita', 0.00037134695089572223),
#  ('region_eastern NC', 0.000370204344892967),
#  ('region_south jersey', 0.0003701680716865288),
#  ('region_roanoke', 0.0003699739033461913),
#  ('region_zanesville / cambridge', 0.00036511112473917217),
#  ('short_model_juke', 0.0003605755828169444),
#  ('short_model_sc', 0.0003605120809993339),
#  ('short_model_xts', 0.0003595213188285079),
#  ('short_model_challenger', 0.0003564930728598933),
#  ('short_model_fiesta', 0.0003564930728598933),
#  ('region_boulder', 0.0003564930728598933),
#  ('region_chillicothe', 0.0003564930728598933),
#  ('region_prescott', 0.0003564930728598933),
#  ('short_model_nitro', 0.00035600870727176866),
#  ('region_rapid city / west SD', 0.00035596881834098256),
#  ('short_model_freestyle', 0.00035277960335093606),
#  ('region_hartford', 0.00035257556656473),
#  ('region_norfolk / hampton roads', 0.00035161054813515367),
#  ('region_milwaukee', 0.0003510339552911701),
#  ('short_model_380sl', 0.0003430346811074661),
#  ('short_model_ilx', 0.0003364770226184639),
#  ('short_model_q7', 0.000334768785177166),
#  ('short_model_international', 0.00033421225580615004),
#  ('short_model_s40', 0.00033421225580615004),
#  ('region_fayetteville', 0.00033421225580615004),
#  ('region_fort collins / north CO', 0.00033421225580615004),
#  ('region_amarillo', 0.0003259601013418006),
#  ('region_tampa bay area', 0.00030326667656483975),
#  ('short_model_expedition', 0.00029707756071657774),
#  ('short_model_willys', 0.00029707756071657774),
#  ('region_athens', 0.00029707756071657774),
#  ('region_los angeles', 0.00029707756071657774),
#  ('region_santa maria', 0.00029707756071657774),
#  ('region_victoria', 0.00029707756071657774),
#  ('state_sc', 0.00029707756071657774),
#  ('short_model_encore', 0.0002411349319982359),
#  ('short_model_cc4500', 0.00022280817053743334),
#  ('short_model_liberty', 0.00022280817053743334),
#  ('region_new york city', 0.00022280817053743334),
#  ('short_model_leaf', 0.000220215720581028),
#  ('region_ventura county', 0.00021896665035575278),
#  ('region_twin falls', 0.00021875736862374061),
#  ('short_model_highlander', 0.0002185233980270989),
#  ('region_seattle-tacoma', 0.0002185119239034278),
#  ('manufacturer_lincoln', 0.00021730673422786745),
#  ('region_pueblo', 0.00021579707356979717),
#  ('region_anchorage / mat-su', 0.00021268052642209537),
#  ('region_bend', 0.0002042408229926475),
#  ('region_phoenix', 0.00014616848067171872),
#  ('region_sacramento', 0.0001452132852756394),
#  ('region_st louis, MO', 0.00010775149230908809),
#  ('short_model_-benz', 0.0),
#  ('short_model_1', 0.0),
#  ('short_model_124', 0.0),
#  ('short_model_128i', 0.0),
#  ('short_model_135i', 0.0),
#  ('short_model_163869', 0.0),
#  ('short_model_1928', 0.0),
#  ('short_model_1951', 0.0),
#  ('short_model_1954', 0.0),
#  ('short_model_1960s', 0.0),
#  ('short_model_1966', 0.0),
#  ('short_model_1968', 0.0),
#  ('short_model_1972', 0.0),
#  ('short_model_1977', 0.0),
#  ('short_model_1978', 0.0),
#  ('short_model_198.5', 0.0),
#  ('short_model_1988', 0.0),
#  ('short_model_1994', 0.0),
#  ('short_model_1999', 0.0),
#  ('short_model_2', 0.0),
#  ('short_model_2000', 0.0),
#  ('short_model_2002', 0.0),
#  ('short_model_2006', 0.0),
#  ('short_model_2007', 0.0),
#  ('short_model_2008', 0.0),
#  ('short_model_2009', 0.0),
#  ('short_model_2012', 0.0),
#  ('short_model_2015', 0.0),
#  ('short_model_2016', 0.0),
#  ('short_model_2017', 0.0),
#  ('short_model_2018', 0.0),
#  ('short_model_210', 0.0),
#  ('short_model_240', 0.0),
#  ('short_model_2500hd', 0.0),
#  ('short_model_280zx', 0.0),
#  ('short_model_3', 0.0),
#  ('short_model_3-series', 0.0),
#  ('short_model_3-window', 0.0),
#  ('short_model_3.2', 0.0),
#  ('short_model_300', 0.0),
#  ('short_model_300-series', 0.0),
#  ('short_model_300c', 0.0),
#  ('short_model_300s', 0.0),
#  ('short_model_300zx', 0.0),
#  ('short_model_3100', 0.0),
#  ('short_model_318i', 0.0),
#  ('short_model_320i', 0.0),
#  ('short_model_323i', 0.0),
#  ('short_model_325ci', 0.0),
#  ('short_model_325i', 0.0),
#  ('short_model_325xi', 0.0),
#  ('short_model_328', 0.0),
#  ('short_model_328ci', 0.0),
#  ('short_model_328d', 0.0),
#  ('short_model_328i', 0.0),
#  ('short_model_330i', 0.0),
#  ('short_model_335i', 0.0),
#  ('short_model_335xi', 0.0),
#  ('short_model_350', 0.0),
#  ('short_model_3500', 0.0),
#  ('short_model_3500hd', 0.0),
#  ('short_model_350z', 0.0),
#  ('short_model_370z', 0.0),
#  ('short_model_3i', 0.0),
#  ('short_model_4', 0.0),
#  ('short_model_4-runner', 0.0),
#  ('short_model_430i', 0.0),
#  ('short_model_435i', 0.0),
#  ('short_model_440xi', 0.0),
#  ('short_model_4500', 0.0),
#  ('short_model_4x4', 0.0),
#  ('short_model_5', 0.0),
#  ('short_model_5-series', 0.0),
#  ('short_model_50', 0.0),
#  ('short_model_500c', 0.0),
#  ('short_model_500l', 0.0),
#  ('short_model_500x', 0.0),
#  ('short_model_525i', 0.0),
#  ('short_model_528i', 0.0),
#  ('short_model_528xi', 0.0),
#  ('short_model_530', 0.0),
#  ('short_model_530i', 0.0),
#  ('short_model_535i', 0.0),
#  ('short_model_535xi', 0.0),
#  ('short_model_540i', 0.0),
#  ('short_model_545i', 0.0),
#  ('short_model_5500', 0.0),
#  ('short_model_5500hd', 0.0),
#  ('short_model_550i', 0.0),
#  ('short_model_5th', 0.0),
#  ('short_model_6', 0.0),
#  ('short_model_640', 0.0),
#  ('short_model_645ci', 0.0),
#  ('short_model_650i', 0.0),
#  ('short_model_650xi', 0.0),
#  ('short_model_7', 0.0),
#  ('short_model_750', 0.0),
#  ('short_model_750i', 0.0),
#  ('short_model_750xi', 0.0),
#  ('short_model_86', 0.0),
#  ('short_model_911', 0.0),
#  ('short_model_914', 0.0),
#  ('short_model_928', 0.0),
#  ('short_model_944', 0.0),
#  ('short_model_ACURA*', 0.0),
#  ('short_model_ALL', 0.0),
#  ('short_model_AM', 0.0),
#  ('short_model_AMC', 0.0),
#  ('short_model_ASC', 0.0),
#  ('short_model_Acuarea', 0.0),
#  ('short_model_American', 0.0),
#  ('short_model_BUY', 0.0),
#  ('short_model_Bentley', 0.0),
#  ('short_model_Blue', 0.0),
#  ('short_model_Buicks', 0.0),
#  ('short_model_C', 0.0),
#  ('short_model_CHEVORLET', 0.0),
#  ('short_model_Champion', 0.0),
#  ('short_model_Chevey', 0.0),
#  ('short_model_Chevorlet', 0.0),
#  ('short_model_Comanche', 0.0),
#  ('short_model_Comet', 0.0),
#  ('short_model_D7FH173552', 0.0),
#  ('short_model_DODGE1500', 0.0),
#  ('short_model_Diahatsu', 0.0),
#  ('short_model_E46', 0.0),
#  ('short_model_EASY', 0.0),
#  ('short_model_Eagle', 0.0),
#  ('short_model_Emergency', 0.0),
#  ('short_model_F-250', 0.0),
#  ('short_model_F250', 0.0),
#  ('short_model_FORD*', 0.0),
#  ('short_model_FORD/RANGER', 0.0),
#  ('short_model_FREIGHTLINER', 0.0),
#  ('short_model_FRRV', 0.0),
#  ('short_model_Flexible', 0.0),
#  ('short_model_FordE350', 0.0),
#  ('short_model_Freightliner', 0.0),
#  ('short_model_Frtlner', 0.0),
#  ('short_model_GCM', 0.0),
#  ('short_model_GEHL', 0.0),
#  ('short_model_GMC,', 0.0),
#  ('short_model_GMX', 0.0),
#  ('short_model_GRAND', 0.0),
#  ('short_model_GULF', 0.0),
#  ('short_model_Genesis', 0.0),
#  ('short_model_Gx', 0.0),
#  ('short_model_HINO', 0.0),
#  ('short_model_HUMMER', 0.0),
#  ('short_model_Hino', 0.0),
#  ('short_model_Hobda', 0.0),
#  ('short_model_Hot', 0.0),
#  ('short_model_Hummer', 0.0),
#  ('short_model_IC', 0.0),
#  ('short_model_INTERNATIONAL', 0.0),
#  ('short_model_International', 0.0),
#  ('short_model_Isizu', 0.0),
#  ('short_model_Isuzu', 0.0),
#  ('short_model_JM1BK32F871604924', 0.0),
#  ('short_model_Janesville', 0.0),
#  ('short_model_Jauguar', 0.0),
#  ('short_model_Jayco', 0.0),
#  ('short_model_Kaiser', 0.0),
#  ('short_model_Lotus', 0.0),
#  ('short_model_MASERATI', 0.0),
#  ('short_model_MERCUTY', 0.0),
#  ('short_model_MERDECES', 0.0),
#  ('short_model_MGB', 0.0),
#  ('short_model_MITUSBISHI', 0.0),
#  ('short_model_MV-1', 0.0),
#  ('short_model_Maserati', 0.0),
#  ('short_model_Minin', 0.0),
#  ('short_model_Nascar', 0.0),
#  ('short_model_OLDSMOBILE', 0.0),
#  ('short_model_PLYMOUTH', 0.0),
#  ('short_model_PROGRAMS', 0.0),
#  ('short_model_Peterbilt', 0.0),
#  ('short_model_Pierce', 0.0),
#  ('short_model_QX', 0.0),
#  ('short_model_S60', 0.0),
#  ('short_model_SCION', 0.0),
#  ('short_model_SL', 0.0),
#  ('short_model_Saab', 0.0),
#  ('short_model_Sea', 0.0),
#  ('short_model_Sterling', 0.0),
#  ('short_model_Studebaker', 0.0),
#  ('short_model_Suzuki', 0.0),
#  ('short_model_THOMAS', 0.0),
#  ('short_model_Thomas', 0.0),
#  ('short_model_Town', 0.0),
#  ('short_model_Triumph', 0.0),
#  ('short_model_Voltswagon', 0.0),
#  ('short_model_Xx', 0.0),
#  ('short_model_a-class', 0.0),
#  ('short_model_a3', 0.0),
#  ('short_model_a3,', 0.0),
#  ('short_model_a5', 0.0),
#  ('short_model_a6', 0.0),
#  ('short_model_a7', 0.0),
#  ('short_model_acadia', 0.0),
#  ('short_model_accent', 0.0),
#  ('short_model_accord', 0.0),
#  ('short_model_all', 0.0),
#  ('short_model_allante', 0.0),
#  ('short_model_allroad', 0.0),
#  ('short_model_am', 0.0),
#  ('short_model_amc', 0.0),
#  ('short_model_arcadia', 0.0),
#  ('short_model_armada', 0.0),
#  ('short_model_arteon', 0.0),
#  ('short_model_ascent', 0.0),
#  ('short_model_aspen', 0.0),
#  ('short_model_astra', 0.0),
#  ('short_model_astro', 0.0),
#  ('short_model_atlas', 0.0),
#  ('short_model_ats', 0.0),
#  ('short_model_aura', 0.0),
#  ('short_model_autobiography', 0.0),
#  ('short_model_avanger', 0.0),
#  ('short_model_aveo', 0.0),
#  ('short_model_aviator', 0.0),
#  ('short_model_azera', 0.0),
#  ('short_model_aztek', 0.0),
#  ('short_model_b-class', 0.0),
#  ('short_model_b-series', 0.0),
#  ('short_model_b2200', 0.0),
#  ('short_model_b2300', 0.0),
#  ('short_model_b2600i', 0.0),
#  ('short_model_baja', 0.0),
#  ('short_model_beetle', 0.0),
#  ('short_model_bel', 0.0),
#  ('short_model_belair', 0.0),
#  ('short_model_benz', 0.0),
#  ('short_model_blackwood', 0.0),
#  ('short_model_blazer', 0.0),
#  ('short_model_blue', 0.0),
#  ('short_model_bolt', 0.0),
#  ('short_model_bonanza', 0.0),
#  ('short_model_bonneville', 0.0),
#  ('short_model_boxster', 0.0),
#  ('short_model_bronco', 0.0),
#  ('short_model_brz', 0.0),
#  ('short_model_bug', 0.0),
#  ('short_model_c', 0.0),
#  ('short_model_c-10', 0.0),
#  ('short_model_c-7500', 0.0),
#  ('short_model_c-class', 0.0),
#  ('short_model_c-hr', 0.0),
#  ('short_model_c-max', 0.0),
#  ('short_model_c/k', 0.0),
#  ('short_model_c10', 0.0),
#  ('short_model_c250', 0.0),
#  ('short_model_c280', 0.0),
#  ('short_model_c30', 0.0),
#  ('short_model_c300', 0.0),
#  ('short_model_c4500', 0.0),
#  ('short_model_c5500', 0.0),
#  ('short_model_c60', 0.0),
#  ('short_model_c6500', 0.0),
#  ('short_model_c70', 0.0),
#  ('short_model_c8500', 0.0),
#  ('short_model_cabellero', 0.0),
#  ('short_model_cabrio', 0.0),
#  ('short_model_caddilac', 0.0),
#  ('short_model_cadenza', 0.0),
#  ('short_model_caliber', 0.0),
#  ('short_model_camary', 0.0),
#  ('short_model_camero', 0.0),
#  ('short_model_canyon', 0.0),
#  ('short_model_capri', 0.0),
#  ('short_model_caprice', 0.0),
#  ('short_model_captiva', 0.0),
#  ('short_model_caravan', 0.0),
#  ('short_model_caravan/grand', 0.0),
#  ('short_model_cargo', 0.0),
#  ('short_model_cascada', 0.0),
#  ('short_model_cavalier', 0.0),
#  ('short_model_cayenne', 0.0),
#  ('short_model_cayman', 0.0),
#  ('short_model_cc', 0.0),
#  ('short_model_cc300', 0.0),
#  ('short_model_century', 0.0),
#  ('short_model_certified', 0.0),
#  ('short_model_charger', 0.0),
#  ('short_model_cherokee', 0.0),
#  ('short_model_chevelle', 0.0),
#  ('short_model_chevorlet', 0.0),
#  ('short_model_chryler', 0.0),
#  ('short_model_chysler', 0.0),
#  ('short_model_city', 0.0),
#  ('short_model_cj-5', 0.0),
#  ('short_model_cj2a', 0.0),
#  ('short_model_cj5', 0.0),
#  ('short_model_cj7', 0.0),
#  ('short_model_cj8', 0.0),
#  ('short_model_cl-class', 0.0),
#  ('short_model_cla', 0.0),
#  ('short_model_cla-class', 0.0),
#  ('short_model_clarity', 0.0),
#  ('short_model_classic', 0.0),
#  ('short_model_classuc', 0.0),
#  ('short_model_clk', 0.0),
#  ('short_model_clk-class', 0.0),
#  ('short_model_clk350', 0.0),
#  ('short_model_cls-class', 0.0),
#  ('short_model_cls550', 0.0),
#  ('short_model_clubman', 0.0),
#  ('short_model_cmax', 0.0),
#  ('short_model_cobalt', 0.0),
#  ('short_model_colbalt', 0.0),
#  ('short_model_comet', 0.0),
#  ('short_model_commander', 0.0),
#  ('short_model_compass', 0.0),
#  ('short_model_concorde', 0.0),
#  ('short_model_conquest', 0.0),
#  ('short_model_continental', 0.0),
#  ('short_model_convertible', 0.0),
#  ('short_model_corsair', 0.0),
#  ('short_model_cougar', 0.0),
#  ('short_model_country', 0.0),
#  ('short_model_countryman', 0.0),
#  ('short_model_coupe', 0.0),
#  ('short_model_crew', 0.0),
#  ('short_model_crossfire', 0.0),
#  ('short_model_crosstour', 0.0),
#  ('short_model_crosstrek', 0.0),
#  ('short_model_crown', 0.0),
#  ('short_model_crv', 0.0),
#  ('short_model_crz', 0.0),
#  ('short_model_ct', 0.0),
#  ('short_model_ct4', 0.0),
#  ('short_model_ct5', 0.0),
#  ('short_model_ct6', 0.0),
#  ('short_model_cts-v', 0.0),
#  ('short_model_cts4', 0.0),
#  ('short_model_cube', 0.0),
#  ('short_model_cvr', 0.0),
#  ('short_model_cx-3', 0.0),
#  ('short_model_cx-7', 0.0),
#  ('short_model_cx-9', 0.0),
#  ('short_model_cx7', 0.0),
#  ('short_model_cx9', 0.0),
#  ('short_model_d50', 0.0),
#  ('short_model_dakota', 0.0),
#  ('short_model_davidson', 0.0),
#  ('short_model_dealer*', 0.0),
#  ('short_model_defender', 0.0),
#  ('short_model_deisel', 0.0),
#  ('short_model_deluxe', 0.0),
#  ('short_model_denali', 0.0),
#  ('short_model_deville', 0.0),
#  ('short_model_diesel', 0.0),
#  ('short_model_discovery', 0.0),
#  ('short_model_dts', 0.0),
#  ('short_model_dump', 0.0),
#  ('short_model_duramax', 0.0),
#  ('short_model_durango', 0.0),
#  ('short_model_durangon', 0.0),
#  ('short_model_e-150', 0.0),
#  ('short_model_e-250', 0.0),
#  ('short_model_e-450', 0.0),
#  ('short_model_e-class', 0.0),
#  ('short_model_e-pace', 0.0),
#  ('short_model_e-series', 0.0),
#  ('short_model_e150', 0.0),
#  ('short_model_e250', 0.0),
#  ('short_model_e320', 0.0),
#  ('short_model_e46', 0.0),
#  ('short_model_e500', 0.0),
#  ('short_model_echo', 0.0),
#  ('short_model_eclipse', 0.0),
#  ('short_model_econoline', 0.0),
#  ('short_model_ecosport', 0.0),
#  ('short_model_el', 0.0),
#  ('short_model_elcamino', 0.0),
#  ('short_model_eldorado', 0.0),
#  ('short_model_element', 0.0),
#  ('short_model_endeavor', 0.0),
#  ('short_model_envision', 0.0),
#  ('short_model_envoy', 0.0),
#  ('short_model_eos', 0.0),
#  ('short_model_eqinox', 0.0),
#  ('short_model_equinox', 0.0),
#  ('short_model_es', 0.0),
#  ('short_model_es300', 0.0),
#  ('short_model_es330', 0.0),
#  ('short_model_es350', 0.0),
#  ('short_model_escape-se,', 0.0),
#  ('short_model_escort', 0.0),
#  ('short_model_evoque', 0.0),
#  ('short_model_f', 0.0),
#  ('short_model_f-100', 0.0),
#  ('short_model_f-350sd', 0.0),
#  ('short_model_f-450', 0.0),
#  ('short_model_f-450sd', 0.0),
#  ('short_model_f-550', 0.0),
#  ('short_model_f-650', 0.0),
#  ('short_model_f-750', 0.0),
#  ('short_model_f-pace', 0.0),
#  ('short_model_f-type', 0.0),
#  ('short_model_f1', 0.0),
#  ('short_model_f100', 0.0),
#  ('short_model_f450', 0.0),
#  ('short_model_f450sd', 0.0),
#  ('short_model_f50', 0.0),
#  ('short_model_f550', 0.0),
#  ('short_model_f600', 0.0),
#  ('short_model_f700', 0.0),
#  ('short_model_f750', 0.0),
#  ('short_model_falcon', 0.0),
#  ('short_model_fe', 0.0),
#  ('short_model_fiero', 0.0),
#  ('short_model_firebird', 0.0),
#  ('short_model_five', 0.0),
#  ('short_model_fj40', 0.0),
#  ('short_model_fleetmaster', 0.0),
#  ('short_model_fleetwood', 0.0),
#  ('short_model_flex', 0.0),
#  ('short_model_fords', 0.0),
#  ('short_model_forester', 0.0),
#  ('short_model_forte5', 0.0),
#  ('short_model_foxbody', 0.0),
#  ('short_model_freestar', 0.0),
#  ('short_model_freightliner', 0.0),
#  ('short_model_fuso', 0.0),
#  ('short_model_fx35', 0.0),
#  ('short_model_fx45', 0.0),
#  ('short_model_g-class', 0.0),
#  ('short_model_g.', 0.0),
#  ('short_model_g20', 0.0),
#  ('short_model_g30', 0.0),
#  ('short_model_g35', 0.0),
#  ('short_model_g35x', 0.0),
#  ('short_model_g37s', 0.0),
#  ('short_model_g37x', 0.0),
#  ('short_model_g4500', 0.0),
#  ('short_model_g5', 0.0),
#  ('short_model_g6', 0.0),
#  ('short_model_g8', 0.0),
#  ('short_model_galant', 0.0),
#  ('short_model_ghia', 0.0),
#  ('short_model_gl', 0.0),
#  ('short_model_gl-class', 0.0),
#  ('short_model_gl450', 0.0),
#  ('short_model_gla', 0.0),
#  ('short_model_gla-class', 0.0),
#  ('short_model_gladiator', 0.0),
#  ('short_model_glc', 0.0),
#  ('short_model_glc-class', 0.0),
#  ('short_model_gle', 0.0),
#  ('short_model_gle-class', 0.0),
#  ('short_model_glk', 0.0),
#  ('short_model_glk-class', 0.0),
#  ('short_model_glk350', 0.0),
#  ('short_model_gls', 0.0),
#  ('short_model_gmc/chev', 0.0),
#  ('short_model_gmce', 0.0),
#  ('short_model_gmt-400', 0.0),
#  ('short_model_gr', 0.0),
#  ('short_model_grandville', 0.0),
#  ('short_model_grumman', 0.0),
#  ('short_model_gs', 0.0),
#  ('short_model_gs350', 0.0),
#  ('short_model_gs430', 0.0),
#  ('short_model_gt', 0.0),
#  ('short_model_gt-r', 0.0),
#  ('short_model_gti', 0.0),
#  ('short_model_gx460', 0.0),
#  ('short_model_gx470', 0.0),
#  ('short_model_hardbody', 0.0),
#  ('short_model_hardtop', 0.0),
#  ('short_model_hearse', 0.0),
#  ('short_model_hhr', 0.0),
#  ('short_model_hiace', 0.0),
#  ('short_model_high', 0.0),
#  ('short_model_hr-v', 0.0),
#  ('short_model_hse', 0.0),
#  ('short_model_hyndai', 0.0),
#  ('short_model_i-miev', 0.0),
#  ('short_model_i30', 0.0),
#  ('short_model_i35', 0.0),
#  ('short_model_insight', 0.0),
#  ('short_model_ion', 0.0),
#  ('short_model_ioniq', 0.0),
#  ('short_model_is250', 0.0),
#  ('short_model_is300', 0.0),
#  ('short_model_isuzu', 0.0),
#  ('short_model_jeepster', 0.0),
#  ('short_model_jimmy', 0.0),
#  ('short_model_jouney', 0.0),
#  ('short_model_journey', 0.0),
#  ('short_model_jx35', 0.0),
#  ('short_model_k10', 0.0),
#  ('short_model_k20', 0.0),
#  ('short_model_k30', 0.0),
#  ('short_model_k5', 0.0),
#  ('short_model_kicks', 0.0),
#  ('short_model_kodiak', 0.0),
#  ('short_model_l', 0.0),
#  ('short_model_l300', 0.0),
#  ('short_model_lacrosse', 0.0),
#  ('short_model_lancer', 0.0),
#  ('short_model_landcruiser', 0.0),
#  ('short_model_legacy', 0.0),
#  ('short_model_legend', 0.0),
#  ('short_model_lemans', 0.0),
#  ('short_model_lesabre', 0.0),
#  ('short_model_lifted', 0.0),
#  ('short_model_lightning', 0.0),
#  ('short_model_limousine', 0.0),
#  ('short_model_long', 0.0),
#  ('short_model_lr2', 0.0),
#  ('short_model_lr3', 0.0),
#  ('short_model_lr4', 0.0),
#  ('short_model_ls', 0.0),
#  ('short_model_ltd', 0.0),
#  ('short_model_lucerne', 0.0),
#  ('short_model_lx', 0.0),
#  ('short_model_m', 0.0),
#  ('short_model_m-class', 0.0),
#  ('short_model_m35', 0.0),
#  ('short_model_m5', 0.0),
#  ('short_model_macan', 0.0),
#  ('short_model_magnum', 0.0),
#  ('short_model_mallinia', 0.0),
#  ('short_model_marineer,premier', 0.0),
#  ('short_model_mariner', 0.0),
#  ('short_model_mark', 0.0),
#  ('short_model_maserati', 0.0),
#  ('short_model_matrix', 0.0),
#  ('short_model_maxima', 0.0),
#  ('short_model_maximum', 0.0),
#  ('short_model_mazda2', 0.0),
#  ('short_model_mazda5', 0.0),
#  ('short_model_mazda6', 0.0),
#  ('short_model_mazda6i', 0.0),
#  ('short_model_md-x', 0.0),
#  ('short_model_mercades', 0.0),
#  ('short_model_mercedes-amg', 0.0),
#  ('short_model_metris', 0.0),
#  ('short_model_mg', 0.0),
#  ('short_model_miata', 0.0),
#  ('short_model_milan', 0.0),
#  ('short_model_mkc', 0.0),
#  ('short_model_mks', 0.0),
#  ('short_model_mkt', 0.0),
#  ('short_model_ml', 0.0),
#  ('short_model_ml350', 0.0),
#  ('short_model_ml500', 0.0),
#  ('short_model_model', 0.0),
#  ('short_model_monte', 0.0),
#  ('short_model_montero', 0.0),
#  ('short_model_mountaineer', 0.0),
#  ('short_model_mpv', 0.0),
#  ('short_model_mr2', 0.0),
#  ('short_model_murano', 0.0),
#  ('short_model_mx-5', 0.0),
#  ('short_model_nautilus', 0.0),
#  ('short_model_navigator', 0.0),
#  ('short_model_neon', 0.0),
#  ('short_model_new', 0.0),
#  ('short_model_newport', 0.0),
#  ('short_model_niro', 0.0),
#  ('short_model_nova', 0.0),
#  ('short_model_nv', 0.0),
#  ('short_model_nv1500', 0.0),
#  ('short_model_nv200', 0.0),
#  ('short_model_nv2500hd', 0.0),
#  ('short_model_nx', 0.0),
#  ('short_model_nx300', 0.0),
#  ('short_model_oddyssey', 0.0),
#  ('short_model_oldsmobile', 0.0),
#  ('short_model_optima', 0.0),
#  ('short_model_optimia', 0.0),
#  ('short_model_outback', 0.0),
#  ('short_model_outlander', 0.0),
#  ('short_model_outlook', 0.0),
#  ('short_model_paceman', 0.0),
#  ('short_model_pacifica', 0.0),
#  ('short_model_panamera', 0.0),
#  ('short_model_panel', 0.0),
#  ('short_model_park', 0.0),
#  ('short_model_passport', 0.0),
#  ('short_model_pathfinder', 0.0),
#  ('short_model_patriot', 0.0),
#  ('short_model_phaeton', 0.0),
#  ('short_model_pick', 0.0),
#  ('short_model_pickup', 0.0),
#  ('short_model_pontaic', 0.0),
#  ('short_model_prelude', 0.0),
#  ('short_model_prizm', 0.0),
#  ('short_model_protege', 0.0),
#  ('short_model_pt', 0.0),
#  ('short_model_putback', 0.0),
#  ('short_model_q3', 0.0),
#  ('short_model_q5', 0.0),
#  ('short_model_q50', 0.0),
#  ('short_model_q60', 0.0),
#  ('short_model_q70', 0.0),
#  ('short_model_quattro', 0.0),
#  ('short_model_quest', 0.0),
#  ('short_model_qx56', 0.0),
#  ('short_model_qx60', 0.0),
#  ('short_model_qx70', 0.0),
#  ('short_model_r-class', 0.0),
#  ('short_model_r32', 0.0),
#  ('short_model_rabbit', 0.0),
#  ('short_model_rainier', 0.0),
#  ('short_model_ram1500', 0.0),
#  ('short_model_ram2500', 0.0),
#  ('short_model_ramcharger', 0.0),
#  ('short_model_range', 0.0),
#  ('short_model_ranger', 0.0),
#  ('short_model_rat', 0.0),
#  ('short_model_rav', 0.0),
#  ('short_model_rc', 0.0),
#  ('short_model_rdx', 0.0),
#  ('short_model_reatta', 0.0),
#  ('short_model_rebel', 0.0),
#  ('short_model_rendezvous', 0.0),
#  ('short_model_replica', 0.0),
#  ('short_model_ridgeline', 0.0),
#  ('short_model_rio', 0.0),
#  ('short_model_rivera', 0.0),
#  ('short_model_riviera', 0.0),
#  ('short_model_rl', 0.0),
#  ('short_model_rlx', 0.0),
#  ('short_model_roadmaster', 0.0),
#  ('short_model_roadster', 0.0),
#  ('short_model_romeo', 0.0),
#  ('short_model_rondo', 0.0),
#  ('short_model_rouge', 0.0),
#  ('short_model_routan', 0.0),
#  ('short_model_rs', 0.0),
#  ('short_model_rsx', 0.0),
#  ('short_model_rx-8', 0.0),
#  ...]

# %%
for i in range(len(f_imp_list)): #переберем из списка всех фич
    if f_imp_list[i][1] == 0: # если значение равно 0
        
        x_train = x_train.drop([f_imp_list[i][0]], axis=1) #удаляем этот столбец из x_train
        x_test = x_test.drop([f_imp_list[i][0]], axis=1) #удаляем этот столбец из x_test
len(x_train.columns) #ПРОВЕРИМ СКОЛЬКО ОСТАЛОСЬ
# Out:
# 364

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
predicted_train = clf.predict(x_train)
predicted_test = clf.predict(x_test)

# %%
print(accuracy_score(y_train, predicted_train))
print(accuracy_score(y_test, predicted_test))
# Out:
# 1.0
# 0.6725571725571725

# %%
confusion_matrix(y_test, predicted_test)
# Out:
# array([[730,  54, 213],
#        [ 42, 696, 215],
#        [192, 229, 515]], dtype=int64)

# %%
clf.feature_importances_
# Out:
# array([3.43353344e-02, 4.13536957e-04, 4.44991971e-03, 5.24521566e-03,
#        7.75102363e-04, 3.42379966e-02, 7.14174583e-04, 3.23547384e-03,
#        1.38580224e-03, 2.63296967e-04, 8.05465929e-02, 7.37481144e-04,
#        0.00000000e+00, 0.00000000e+00, 4.22115231e-04, 3.88250368e-04,
#        4.13160898e-04, 3.69755981e-04, 4.40719458e-04, 1.63088847e-03,
#        8.26908290e-04, 4.13823124e-04, 4.05105765e-04, 4.86574638e-03,
#        3.99860764e-04, 0.00000000e+00, 1.50621010e-03, 1.07127428e-03,
#        0.00000000e+00, 4.11338161e-04, 4.14208499e-04, 4.25361053e-04,
#        9.67613448e-04, 0.00000000e+00, 4.32112816e-04, 4.40646208e-04,
#        1.22216638e-03, 6.90321136e-04, 2.52779092e-03, 1.79236352e-03,
#        0.00000000e+00, 2.55511006e-03, 3.89688784e-04, 7.44550637e-04,
#        6.11716783e-04, 4.31138600e-04, 7.22584684e-04, 4.29829245e-04,
#        7.93005914e-04, 0.00000000e+00, 4.36332667e-04, 1.42139074e-03,
#        0.00000000e+00, 6.44259866e-04, 9.13390215e-04, 2.30900787e-03,
#        4.26688468e-04, 4.08623506e-04, 2.97077561e-04, 7.39779682e-04,
#        1.27922381e-03, 7.03311897e-03, 2.59381299e-03, 6.13900862e-04,
#        1.10811067e-03, 3.24788542e-03, 1.73684820e-03, 4.09056882e-04,
#        8.39521675e-04, 0.00000000e+00, 8.37939767e-04, 2.43431641e-03,
#        2.39958862e-03, 3.96686784e-04, 3.52779603e-04, 3.99432014e-04,
#        1.12845341e-03, 1.25206494e-03, 4.16817472e-04, 4.29380395e-04,
#        7.15506717e-04, 1.02585207e-03, 8.22814425e-04, 1.26151503e-03,
#        6.57176984e-04, 5.34537520e-04, 4.20061199e-04, 3.36477023e-04,
#        1.57178912e-03, 3.55865444e-04, 0.00000000e+00, 3.89343191e-04,
#        3.71812590e-04, 2.20279849e-03, 3.79243304e-04, 4.22162849e-04,
#        9.21252063e-04, 2.18511924e-04, 7.71273716e-04, 4.17894078e-04,
#        7.53177458e-04, 4.29380395e-04, 6.70668623e-04, 1.13746286e-03,
#        7.06504850e-04, 0.00000000e+00, 4.20646973e-04, 4.71350581e-04,
#        2.02569954e-03, 3.56008707e-04, 0.00000000e+00, 1.00575469e-03,
#        1.12070862e-03, 0.00000000e+00, 1.03977146e-03, 3.90142898e-04,
#        4.30980206e-04, 9.17131844e-04, 4.21776444e-04, 0.00000000e+00,
#        4.19098922e-04, 3.66381572e-04, 1.38837392e-03, 8.37990711e-04,
#        5.97627133e-04, 6.78669626e-04, 4.29479275e-04, 3.34212256e-04,
#        7.15808219e-04, 3.34768785e-04, 4.11338161e-04, 2.45222580e-03,
#        3.95920227e-04, 3.24893961e-03, 5.88834161e-03, 8.28207769e-04,
#        3.90142898e-04, 2.28227832e-03, 4.40925643e-04, 4.12480767e-04,
#        1.09173602e-03, 4.17953435e-03, 2.08598529e-03, 1.15372404e-03,
#        2.21939523e-04, 1.10187171e-03, 9.99841683e-04, 0.00000000e+00,
#        1.92293645e-03, 0.00000000e+00, 1.93297410e-03, 3.84136766e-04,
#        1.29421141e-03, 2.94425082e-04, 8.76784632e-03, 1.86576550e-03,
#        3.95777671e-04, 3.48459124e-04, 4.31451242e-04, 0.00000000e+00,
#        4.20859878e-04, 6.58141058e-04, 2.24832792e-03, 1.51423798e-03,
#        1.17317958e-03, 4.00928410e-04, 4.27791687e-04, 4.22162849e-04,
#        3.85935581e-04, 0.00000000e+00, 2.12680526e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 5.60733896e-04, 0.00000000e+00,
#        0.00000000e+00, 7.79153173e-04, 4.01054707e-04, 3.40380392e-04,
#        4.82100963e-04, 5.02895696e-04, 0.00000000e+00, 4.03578803e-04,
#        0.00000000e+00, 4.09056882e-04, 1.68039063e-03, 8.07464136e-04,
#        4.25028712e-04, 0.00000000e+00, 1.12270947e-03, 0.00000000e+00,
#        8.79276000e-04, 3.60512081e-04, 4.36071724e-04, 4.10753043e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.13963697e-03,
#        1.62387778e-03, 4.05840650e-04, 5.29378811e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.11338161e-04, 4.01054707e-04,
#        1.15424294e-03, 2.11758526e-04, 6.96772022e-04, 4.26863401e-04,
#        1.22786474e-03, 8.65771564e-04, 4.25017757e-04, 8.80010172e-04,
#        7.74218191e-04, 1.07491356e-03, 4.02618273e-04, 4.23431870e-04,
#        5.85377830e-04, 3.03480094e-04, 1.14398848e-03, 4.16332645e-04,
#        0.00000000e+00, 4.37208486e-04, 4.23335524e-04, 6.14768666e-04,
#        4.07900755e-04, 1.25275937e-03, 0.00000000e+00, 4.28477251e-04,
#        4.18712976e-04, 1.37955112e-03, 1.46168481e-04, 8.20922442e-04,
#        7.77342014e-04, 0.00000000e+00, 2.15797074e-04, 1.20127647e-03,
#        0.00000000e+00, 7.03995229e-04, 2.15679723e-04, 4.09819833e-04,
#        1.09045248e-03, 5.43160960e-04, 3.87617307e-04, 8.92780922e-04,
#        3.98040877e-04, 4.01054707e-04, 1.19760516e-03, 0.00000000e+00,
#        3.83464588e-04, 0.00000000e+00, 4.24396515e-04, 2.55670024e-03,
#        3.94884635e-04, 8.18537862e-04, 1.10780445e-03, 3.95113156e-04,
#        1.07751492e-04, 4.25361053e-04, 0.00000000e+00, 3.89914298e-04,
#        3.91216424e-04, 0.00000000e+00, 4.11906257e-04, 1.54687339e-03,
#        4.23576356e-04, 2.15307132e-04, 2.18966650e-04, 6.18911585e-04,
#        0.00000000e+00, 4.30571852e-04, 9.88706054e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.27791687e-04,
#        7.53474626e-04, 0.00000000e+00, 0.00000000e+00, 3.69732785e-04,
#        1.13882577e-03, 0.00000000e+00, 3.76070495e-03, 2.00714803e-03,
#        1.61988696e-03, 1.21439815e-03, 2.87517973e-03, 3.66630465e-03,
#        3.51337958e-03, 4.31086868e-03, 3.31288765e-03, 6.35446527e-03,
#        0.00000000e+00, 1.97168817e-03, 9.48109526e-03, 1.59001836e-03,
#        6.25788380e-04, 5.26790364e-04, 4.61426659e-03, 7.12429821e-04,
#        3.73979923e-03, 3.51199756e-03, 1.45515072e-03, 0.00000000e+00,
#        9.32504438e-03, 3.38325931e-03, 9.23073291e-04, 2.43316896e-03,
#        5.37766748e-03, 7.46220163e-04, 3.52145596e-04, 1.65302443e-03,
#        6.66302529e-04, 4.04700659e-04, 3.28907299e-04, 9.35349661e-04,
#        1.15879666e-03, 1.56545001e-03, 8.02496993e-04, 1.20581947e-03,
#        4.15908585e-04, 0.00000000e+00, 8.62875279e-04, 0.00000000e+00,
#        1.44339890e-03, 6.69426798e-04, 1.86800661e-03, 1.52210670e-03,
#        1.93279215e-03, 7.33418852e-04, 0.00000000e+00, 1.44335775e-03,
#        1.35880869e-03, 7.68269376e-04, 1.20070752e-03, 1.53862405e-03,
#        1.36333911e-03, 1.77755961e-03, 4.07795122e-04, 0.00000000e+00,
#        1.36931333e-03, 1.10929192e-03, 1.40703226e-03, 1.79063232e-03,
#        1.18960911e-03, 2.68198790e-03, 9.20849222e-04, 1.22173147e-03,
#        0.00000000e+00, 0.00000000e+00, 4.36050151e-02, 4.00665889e-02,
#        2.18080513e-01, 7.10348637e-02, 4.07666173e-03, 8.00159550e-02,
#        6.87629817e-03, 2.39147436e-03, 1.27835095e-02, 2.54335276e-02])

# %%
f_imp_list = list(zip(x_train.columns, clf.feature_importances_))
f_imp_list
# Out:
# [('id', 0.03433533441946541),
#  ('is_audi', 0.0004135369574176561),
#  ('is_ford', 0.004449919708662052),
#  ('is_chevrolet', 0.005245215659415799),
#  ('is_toyota', 0.0007751023629605245),
#  ('x0_diesel', 0.03423799658843502),
#  ('x0_electric', 0.0007141745827292685),
#  ('x0_gas', 0.0032354738397729027),
#  ('x0_hybrid', 0.0013858022386644174),
#  ('x0_other', 0.00026329696711896927),
#  ('std_scaled_odometer', 0.08054659290927571),
#  ('short_model_1500', 0.0007374811437909025),
#  ('short_model_200', 0.0),
#  ('short_model_2500', 0.0),
#  ('short_model_325is', 0.00042211523055373445),
#  ('short_model_328xi', 0.0003882503682906916),
#  ('short_model_330xi', 0.0004131608979428074),
#  ('short_model_380sl', 0.0003697559805121375),
#  ('short_model_428', 0.0004407194582059117),
#  ('short_model_4runner', 0.0016308884701415102),
#  ('short_model_500', 0.0008269082904487314),
#  ('short_model_CLICK', 0.0004138231241984923),
#  ('short_model_Plymouth', 0.00040510576461351503),
#  ('short_model_Scion', 0.004865746378858322),
#  ('short_model_a4', 0.0003998607643662992),
#  ('short_model_a8', 0.0),
#  ('short_model_altima', 0.001506210102227363),
#  ('short_model_avalanche', 0.0010712742846942895),
#  ('short_model_avalon', 0.0),
#  ('short_model_avenger', 0.0004113381609921843),
#  ('short_model_bus', 0.0004142084988152229),
#  ('short_model_camaro', 0.000425361052844191),
#  ('short_model_camry', 0.0009676134483071039),
#  ('short_model_cc4500', 0.0),
#  ('short_model_challenger', 0.0004321128155877491),
#  ('short_model_civic', 0.00044064620817264687),
#  ('short_model_colorado', 0.001222166383386595),
#  ('short_model_cooper', 0.0006903211360097658),
#  ('short_model_corolla', 0.0025277909249042897),
#  ('short_model_corvette', 0.0017923635218132091),
#  ('short_model_cr-v', 0.0),
#  ('short_model_cruze', 0.0025551100565458632),
#  ('short_model_cts', 0.0003896887840978581),
#  ('short_model_cx-5', 0.0007445506365459237),
#  ('short_model_dart', 0.0006117167827102284),
#  ('short_model_e', 0.0004311386004188264),
#  ('short_model_e-350', 0.0007225846838175723),
#  ('short_model_e-golf', 0.0004298292450102766),
#  ('short_model_e350', 0.0007930059142270696),
#  ('short_model_e450', 0.0),
#  ('short_model_edge', 0.000436332667302474),
#  ('short_model_elantra', 0.0014213907381493017),
#  ('short_model_enclave', 0.0),
#  ('short_model_encore', 0.000644259865869566),
#  ('short_model_escalade', 0.0009133902146287338),
#  ('short_model_escape', 0.0023090078691346363),
#  ('short_model_eurovan', 0.0004266884680335943),
#  ('short_model_excursion', 0.0004086235064132008),
#  ('short_model_expedition', 0.0002970775607165777),
#  ('short_model_explorer', 0.0007397796824623638),
#  ('short_model_express', 0.0012792238133895522),
#  ('short_model_f-150', 0.00703311897225851),
#  ('short_model_f-250', 0.0025938129854864676),
#  ('short_model_f-250sd', 0.0006139008617778531),
#  ('short_model_f-350', 0.0011081106692366364),
#  ('short_model_f150', 0.0032478854154885696),
#  ('short_model_f250', 0.0017368482005553855),
#  ('short_model_f350', 0.000409056882225924),
#  ('short_model_f650', 0.0008395216748567141),
#  ('short_model_fiesta', 0.0),
#  ('short_model_fit', 0.0008379397670459228),
#  ('short_model_fj', 0.0024343164072529117),
#  ('short_model_focus', 0.002399588620061164),
#  ('short_model_forte', 0.00039668678441625086),
#  ('short_model_freestyle', 0.00035277960335093595),
#  ('short_model_frontier', 0.0003994320144088439),
#  ('short_model_fusion', 0.0011284534112309579),
#  ('short_model_g', 0.0012520649400646782),
#  ('short_model_g37', 0.00041681747156262244),
#  ('short_model_genesis', 0.0004293803948929759),
#  ('short_model_golf', 0.0007155067172600588),
#  ('short_model_grand', 0.0010258520675765547),
#  ('short_model_gto', 0.000822814424883568),
#  ('short_model_gx', 0.0012615150332250461),
#  ('short_model_highlander', 0.0006571769837726706),
#  ('short_model_hummer', 0.0005345375202333474),
#  ('short_model_i3', 0.00042006119924662517),
#  ('short_model_ilx', 0.0003364770226184638),
#  ('short_model_impala', 0.0015717891168086462),
#  ('short_model_impreza', 0.0003558654442104918),
#  ('short_model_international', 0.0),
#  ('short_model_is', 0.0003893431906896444),
#  ('short_model_isf', 0.00037181258970562375),
#  ('short_model_jetta', 0.0022027984922679384),
#  ('short_model_juke', 0.0003792433044816493),
#  ('short_model_k900', 0.00042216284943934743),
#  ('short_model_land', 0.0009212520626853584),
#  ('short_model_leaf', 0.00021851192390342773),
#  ('short_model_liberty', 0.0007712737163224137),
#  ('short_model_lx450', 0.0004178940782481988),
#  ('short_model_m3', 0.0007531774577934246),
#  ('short_model_m35s', 0.0004293803948929759),
#  ('short_model_malibu', 0.0006706686226824554),
#  ('short_model_mazda3', 0.0011374628646186908),
#  ('short_model_mdx', 0.0007065048495219291),
#  ('short_model_mirage', 0.0),
#  ('short_model_mkx', 0.00042064697289007346),
#  ('short_model_mkz', 0.0004713505807531833),
#  ('short_model_mustang', 0.0020256995386495414),
#  ('short_model_nitro', 0.0003560087072717685),
#  ('short_model_nv2500', 0.0),
#  ('short_model_odyssey', 0.0010057546927817267),
#  ('short_model_other', 0.0011207086215263516),
#  ('short_model_passat', 0.0),
#  ('short_model_pilot', 0.001039771462508022),
#  ('short_model_plymouth', 0.0003901428977946836),
#  ('short_model_prius', 0.0004309802062245463),
#  ('short_model_promaster', 0.000917131843894454),
#  ('short_model_q7', 0.0004217764442643094),
#  ('short_model_qx50', 0.0),
#  ('short_model_qx80', 0.0004190989217499753),
#  ('short_model_rav4', 0.00036638157203594974),
#  ('short_model_regal', 0.0013883739152921644),
#  ('short_model_renegade', 0.0008379907105047474),
#  ('short_model_rogue', 0.000597627133072024),
#  ('short_model_rx', 0.0006786696263304665),
#  ('short_model_s-class', 0.00042947927462233076),
#  ('short_model_s40', 0.0003342122558061499),
#  ('short_model_santa', 0.0007158082191375941),
#  ('short_model_sc', 0.0003347687851771659),
#  ('short_model_sedona', 0.0004113381609921843),
#  ('short_model_sentra', 0.002452225798406191),
#  ('short_model_sienna', 0.0003959202269275115),
#  ('short_model_sierra', 0.003248939608913921),
#  ('short_model_silverado', 0.005888341612947565),
#  ('short_model_sonic', 0.000828207769020949),
#  ('short_model_sorento', 0.0003901428977946836),
#  ('short_model_spark', 0.00228227831680646),
#  ('short_model_sportage', 0.0004409256427477633),
#  ('short_model_sprinter', 0.00041248076699494066),
#  ('short_model_super', 0.001091736023126911),
#  ('short_model_tacoma', 0.004179534349536555),
#  ('short_model_tahoe', 0.002085985285268339),
#  ('short_model_taurus', 0.0011537240398303507),
#  ('short_model_tiguan', 0.00022193952269908052),
#  ('short_model_titan', 0.001101871707025397),
#  ('short_model_transit', 0.0009998416828418157),
#  ('short_model_traverse', 0.0),
#  ('short_model_trax', 0.0019229364524543896),
#  ('short_model_tribeca', 0.0),
#  ('short_model_tundra', 0.0019329740984167568),
#  ('short_model_verano', 0.0003841367664749593),
#  ('short_model_versa', 0.001294211408958531),
#  ('short_model_willys', 0.000294425082495894),
#  ('short_model_wrangler', 0.008767846324412219),
#  ('short_model_x5', 0.001865765495065053),
#  ('short_model_xc90', 0.000395777671349387),
#  ('short_model_xts', 0.0003484591244030139),
#  ('short_model_yaris', 0.0004314512421612664),
#  ('short_model_yukon', 0.0),
#  ('short_model_z3', 0.00042085987768181843),
#  ('short_model_z4', 0.0006581410575874952),
#  ('transmission_automatic', 0.0022483279156046807),
#  ('transmission_manual', 0.0015142379828180547),
#  ('transmission_other', 0.0011731795844944096),
#  ('region_SF bay area', 0.00040092841041345945),
#  ('region_abilene', 0.00042779168743187175),
#  ('region_akron / canton', 0.00042216284943934743),
#  ('region_albuquerque', 0.00038593558110948357),
#  ('region_amarillo', 0.0),
#  ('region_anchorage / mat-su', 0.0002126805264220953),
#  ('region_athens', 0.0),
#  ('region_bakersfield', 0.0),
#  ('region_baltimore', 0.0),
#  ('region_bend', 0.0005607338958525406),
#  ('region_birmingham', 0.0),
#  ('region_bloomington-normal', 0.0),
#  ('region_boise', 0.0007791531732440383),
#  ('region_boulder', 0.00040105470696738),
#  ('region_buffalo', 0.00034038039160069007),
#  ('region_central NJ', 0.00048210096262667977),
#  ('region_charlotte', 0.0005028956956147924),
#  ('region_charlottesville', 0.0),
#  ('region_chicago', 0.0004035788032277414),
#  ('region_chillicothe', 0.0),
#  ('region_cincinnati', 0.000409056882225924),
#  ('region_colorado springs', 0.0016803906333131178),
#  ('region_columbus', 0.0008074641364085077),
#  ('region_corpus christi', 0.0004250287121910085),
#  ('region_corvallis/albany', 0.0),
#  ('region_dallas / fort worth', 0.0011227094664582361),
#  ('region_danville', 0.0),
#  ('region_denver', 0.000879276000139468),
#  ('region_des moines', 0.00036051208099933377),
#  ('region_detroit metro', 0.0004360717237046999),
#  ('region_eastern NC', 0.00041075304269774327),
#  ('region_eastern panhandle', 0.0),
#  ('region_erie', 0.0),
#  ('region_fayetteville', 0.0),
#  ('region_flint', 0.0011396369737110249),
#  ('region_fort collins / north CO', 0.0016238777753789706),
#  ('region_fredericksburg', 0.00040584065035431216),
#  ('region_fresno / madera', 0.0005293788112017209),
#  ('region_ft myers / SW florida', 0.0),
#  ('region_grand rapids', 0.0),
#  ('region_greenville / upstate', 0.0),
#  ('region_hartford', 0.0004113381609921843),
#  ('region_indianapolis', 0.00040105470696738),
#  ('region_inland empire', 0.001154242944018636),
#  ('region_kalispell', 0.00021175852611728796),
#  ('region_kansas city, MO', 0.0006967720224425804),
#  ('region_la crosse', 0.00042686340074714525),
#  ('region_lakeland', 0.0012278647385534547),
#  ('region_lansing', 0.0008657715643989714),
#  ('region_lawrence', 0.00042501775729442815),
#  ('region_little rock', 0.0008800101717182148),
#  ('region_long island', 0.00077421819066219),
#  ('region_los angeles', 0.0010749135642025437),
#  ('region_madison', 0.0004026182730764139),
#  ('region_maine', 0.00042343187014034817),
#  ('region_memphis', 0.0005853778298665295),
#  ('region_milwaukee', 0.00030348009435271056),
#  ('region_minneapolis / st paul', 0.0011439884827324617),
#  ('region_missoula', 0.00041633264496299143),
#  ('region_modesto', 0.0),
#  ('region_nashville', 0.0004372084855828874),
#  ('region_new york city', 0.00042333552402112304),
#  ('region_norfolk / hampton roads', 0.0006147686664624692),
#  ('region_olympic peninsula', 0.00040790075517844283),
#  ('region_omaha / council bluffs', 0.0012527593694248763),
#  ('region_orange county', 0.0),
#  ('region_orlando', 0.0004284772510335258),
#  ('region_palm springs', 0.0004187129757073545),
#  ('region_philadelphia', 0.0013795511234134662),
#  ('region_phoenix', 0.00014616848067171867),
#  ('region_pittsburgh', 0.0008209224416132372),
#  ('region_portland', 0.0007773420144720389),
#  ('region_prescott', 0.0),
#  ('region_pueblo', 0.00021579707356979709),
#  ('region_raleigh / durham / CH', 0.0012012764701360556),
#  ('region_rapid city / west SD', 0.0),
#  ('region_redding', 0.00070399522897482),
#  ('region_reno / tahoe', 0.00021567972298718515),
#  ('region_roanoke', 0.0004098198331957291),
#  ('region_rochester', 0.00109045247594717),
#  ('region_sacramento', 0.0005431609603409854),
#  ('region_saginaw-midland-baycity', 0.0003876173069916691),
#  ('region_san antonio', 0.0008927809219407675),
#  ('region_san diego', 0.0003980408766412702),
#  ('region_santa barbara', 0.00040105470696738),
#  ('region_santa fe / taos', 0.0011976051584861893),
#  ('region_santa maria', 0.0),
#  ('region_sarasota-bradenton', 0.00038346458824074065),
#  ('region_seattle-tacoma', 0.0),
#  ('region_south dakota', 0.00042439651530939683),
#  ('region_south florida', 0.002556700235219495),
#  ('region_south jersey', 0.0003948846345524969),
#  ('region_southern illinois', 0.0008185378615672284),
#  ("region_spokane / coeur d'alene", 0.001107804452123372),
#  ('region_st cloud', 0.0003951131557530468),
#  ('region_st louis, MO', 0.00010775149230908806),
#  ('region_stockton', 0.000425361052844191),
#  ('region_tallahassee', 0.0),
#  ('region_tampa bay area', 0.0003899142984405082),
#  ('region_texarkana', 0.0003912164241124802),
#  ('region_toledo', 0.0),
#  ('region_tri-cities', 0.0004119062569999708),
#  ('region_tucson', 0.0015468733891665332),
#  ('region_tuscaloosa', 0.00042357635572567705),
#  ('region_twin falls', 0.00021530713185482898),
#  ('region_ventura county', 0.00021896665035575272),
#  ('region_vermont', 0.0006189115848262035),
#  ('region_victoria', 0.0),
#  ('region_visalia-tulare', 0.0004305718520500224),
#  ('region_wenatchee', 0.0009887060538278304),
#  ('region_western massachusetts', 0.0),
#  ('region_wichita', 0.0),
#  ('region_wilmington', 0.0),
#  ('region_winston-salem', 0.0),
#  ('region_worcester / central MA', 0.00042779168743187175),
#  ('region_yakima', 0.0007534746255030679),
#  ('region_youngstown', 0.0),
#  ('region_yuba-sutter', 0.0),
#  ('region_zanesville / cambridge', 0.0003697327845459976),
#  ('manufacturer_acura', 0.0011388257732422534),
#  ('manufacturer_audi', 0.0),
#  ('manufacturer_bmw', 0.003760704953247601),
#  ('manufacturer_buick', 0.002007148027832335),
#  ('manufacturer_cadillac', 0.0016198869623555586),
#  ('manufacturer_chevrolet', 0.001214398146307388),
#  ('manufacturer_chrysler', 0.0028751797308343447),
#  ('manufacturer_dodge', 0.00366630464735472),
#  ('manufacturer_ford', 0.003513379581706416),
#  ('manufacturer_gmc', 0.004310868680836743),
#  ('manufacturer_honda', 0.0033128876504121634),
#  ('manufacturer_hyundai', 0.00635446526672361),
#  ('manufacturer_jaguar', 0.0),
#  ('manufacturer_jeep', 0.001971688171690823),
#  ('manufacturer_kia', 0.009481095257411705),
#  ('manufacturer_lexus', 0.0015900183577981213),
#  ('manufacturer_lincoln', 0.0006257883802131618),
#  ('manufacturer_mazda', 0.0005267903640974248),
#  ('manufacturer_mercedes-benz', 0.004614266590743073),
#  ('manufacturer_mini', 0.0007124298206997197),
#  ('manufacturer_mitsubishi', 0.003739799232288969),
#  ('manufacturer_nissan', 0.0035119975635567414),
#  ('manufacturer_other', 0.0014551507230858604),
#  ('manufacturer_porsche', 0.0),
#  ('manufacturer_ram', 0.009325044380545055),
#  ('manufacturer_rover', 0.003383259305151962),
#  ('manufacturer_subaru', 0.0009230732906822191),
#  ('manufacturer_toyota', 0.002433168962120507),
#  ('manufacturer_volkswagen', 0.005377667480977611),
#  ('manufacturer_volvo', 0.0007462201625148056),
#  ('state_ak', 0.00035214559636160154),
#  ('state_ca', 0.0016530244271301),
#  ('state_co', 0.000666302529035753),
#  ('state_de', 0.00040470065884890075),
#  ('state_fl', 0.0003289072993647825),
#  ('state_ia', 0.0009353496613322001),
#  ('state_id', 0.00115879665513499),
#  ('state_il', 0.0015654500127261861),
#  ('state_in', 0.0008024969934040153),
#  ('state_ky', 0.0012058194666668437),
#  ('state_la', 0.00041590858500320884),
#  ('state_ma', 0.0),
#  ('state_md', 0.0008628752786267868),
#  ('state_me', 0.0),
#  ('state_mi', 0.001443398899984876),
#  ('state_mn', 0.0006694267975796293),
#  ('state_ms', 0.0018680066143316751),
#  ('state_mt', 0.0015221067047892177),
#  ('state_nc', 0.001932792153358107),
#  ('state_ne', 0.0007334188516287817),
#  ('state_nh', 0.0),
#  ('state_nj', 0.0014433577549840954),
#  ('state_nm', 0.0013588086857167256),
#  ('state_nv', 0.0007682693760035103),
#  ('state_ny', 0.0012007075179962141),
#  ('state_oh', 0.0015386240526807178),
#  ('state_ok', 0.0013633391115359546),
#  ('state_pa', 0.0017775596102658938),
#  ('state_sc', 0.00040779512221052894),
#  ('state_sd', 0.0),
#  ('state_tx', 0.0013693133277873591),
#  ('state_va', 0.0011092919237658562),
#  ('state_wi', 0.0014070322616001627),
#  ('title_status_clean', 0.0017906323164170036),
#  ('title_status_lien', 0.0011896091137717749),
#  ('title_status_rebuilt', 0.002681987900365827),
#  ('title_status_salvage', 0.0009208492217757936),
#  ('age_category_average', 0.001221731468446926),
#  ('age_category_new', 0.0),
#  ('age_category_old', 0.0),
#  ('lat_std', 0.043605015062739165),
#  ('long_std', 0.04006658893659969),
#  ('year_std', 0.21808051250190758),
#  ('desc_len_std', 0.07103486372881393),
#  ('model_in_desc_std', 0.004076661731464998),
#  ('model_len_std', 0.08001595498452174),
#  ('model_word_count_std', 0.006876298165818259),
#  ('month_std', 0.00239147436376845),
#  ('dayofweek_std', 0.012783509513004832),
#  ('diff_years_std', 0.025433527558921178)]

# %%
f_imp_list.sort(key = lambda x: x[1], reverse=True)
len(f_imp_list)
# Out:
# 364

# %% [markdown]
# 2. Подготовка модели случайного леса
#
# Обучите простую модель классификации с помощью RandomForestClassifier. Для этого на новых урезанных семплах тренировочной и тестовой выборок обучите модель случайного леса с зафиксированным random_state=50.

# %%
# Ваш код здесь 
# импортируем классификатор случайного леса
from sklearn.ensemble import RandomForestClassifier
# создаем отдельную переменную rf_clf для классификатора случайного леса
rf_clf = RandomForestClassifier(random_state=50)
# обучим эту переменную
rf_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=50)

# %% [markdown]
# 2. Сделайте предикт, посчитайте точность модели и матрицу ошибок. Сравните с предыдущей моделью дерева решений. Есть ли случаи, когда модель из пункта 1 отрабатывает лучше, чем модель случайного леса?

# %%
# Ваш код здесь 
# выведем предсказанные моделью в predicted_train_rf и predicted_test_rf
predicted_train_rf = rf_clf.predict(x_train)
predicted_test_rf = rf_clf.predict(x_test)
# посчитаем доли правильно предугаданных значений
print(accuracy_score(y_train, predicted_train_rf))
print(accuracy_score(y_test, predicted_test_rf))
# Out:
# 1.0
# 0.7418572418572419

# %% [markdown]
# Модель случайного леса показывает 0.74 против 0.67 модели из пункта 1

# %% [markdown]
# 3. Тюнинг модели случайного леса
#
# Увеличьте точность модели на тестовом датасете RandomForestClassifier c помощью тюнинга параметров.
#
# Параметры, которые можно настраивать для увеличения точности:
# ```
#     `bootstrap'
#     'max_depth'
#     'max_features'
#     'min_samples_leaf'
#     'min_samples_split'
#     'random_state'
#     'n_estimators'
#
# ```
#
# С описанием каждого из параметров можно ознакомиться [в документации](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html).
#
# Задание засчитывается, если значение метрики строго выше 0.76 на тестовом датасете.

# %%
# Ваш код здесь 
# создаем отдельную переменную rf_clf для классификатора случайного леса
rf_clf = RandomForestClassifier(random_state=50, n_estimators=200, min_samples_split=3,
                                max_depth=35, max_features='auto', min_samples_leaf=1,
                                bootstrap=False)
# обучим эту переменную
rf_clf.fit(x_train, y_train)
predicted_train_rf = rf_clf.predict(x_train)
predicted_test_rf = rf_clf.predict(x_test)
# посчитаем доли правильно предугаданных значений
print(accuracy_score(y_train, predicted_train_rf))
print(accuracy_score(y_test, predicted_test_rf))
# Out:
# 1.0
# 0.7671517671517671

# %% [markdown]
# 4. Анализ влияния фичей на модель
#
# До этого в задачах вы работали над подготовленным датасетом, где фичи были заранее извлечены из текстовых переменных, отскейлены и пропущены через OneHotEncoder. Сравним, какой была бы предсказательная способность модели, если бы мы использовали только сырые данные из исходного датасета. Для этого проделайте следующие шаги:
#
# 1. Загрузите датасет `vehicles_dataset_old.csv`.
# 2. Удалите из него переменную `price` и все строковые колонки. Дерево решений и случайный лес не умеют самостоятельно работать со строковыми значениями.
# 3. Сформируйте x_train и x_test так же, как они были сформированы в предыдущих заданиях.
# 4. Обучите свою лучшую модель случайного леса на новых данных и замерьте качество. Убедитесь, что оно ухудшилось.
# 5. Найдите три фичи, которые лучшим образом повлияли на предсказательную способность модели.

# %%
df_old = pd.read_csv('data/vehicles_dataset_old.csv')
df_old.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7303797340  https://knoxville.craigslist.org/ctd/d/knoxvil...
#
#          region                           region_url  price  year  \
# 0   chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1  north jersey     https://newjersey.craigslist.org  16942  2016
# 2  reno / tahoe          https://reno.craigslist.org  35590  2017
# 3  fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4     knoxville     https://knoxville.craigslist.org  14590  2012
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# 1         ford    explorer 4wd 4dr xlt   other     60023        clean
# 2   volkswagen        golf r hatchback     gas     14048        clean
# 3       toyota                    rav4     gas    117291        clean
# 4          bmw  1 series 128i coupe 2d   other     80465        clean
#
#   transmission                                          image_url  \
# 0        other  https://images.craigslist.org/00N0N_1xMPvfxRAI...
# 1    automatic  https://images.craigslist.org/00x0x_26jl9F0cnL...
# 2        other  https://images.craigslist.org/00y0y_eeZjWeiSfb...
# 3    automatic  https://images.craigslist.org/00606_iGe5iXidib...
# 4        other  https://images.craigslist.org/00F0F_5UAXmOzC18...
#
#                                          description state        lat  \
# 0  Carvana is the safer way to buy a car During t...    tn  35.060000
# 1  ***Call Us for more information at: 201-635-14...    nj  40.821805
# 2  Carvana is the safer way to buy a car During t...    ca  33.779214
# 3  2013 Toyota RAV4 XLE 4dr SUV     Offered by: R...    nc  35.715954
# 4  Carvana is the safer way to buy a car During t...    tn  35.970000
#
#         long              posting_date price_category  \
# 0 -85.250000  2021-04-17T12:30:50-0400           high
# 1 -74.061962  2021-05-03T15:40:21-0400         medium
# 2 -84.411811  2021-04-28T03:52:20-0700           high
# 3 -78.655304  2021-04-17T10:08:57-0400         medium
# 4 -83.940000  2021-04-08T15:10:56-0400         medium
#
#                         date
# 0  2021-04-17 16:30:50+00:00
# 1  2021-05-03 19:40:21+00:00
# 2  2021-04-28 10:52:20+00:00
# 3  2021-04-17 14:08:57+00:00
# 4  2021-04-08 19:10:56+00:00

# %%
df_old.shape # проверим размерностьи
# Out:
# (9619, 20)

# %%
# Ваш код здесь
df_old_processed = df_old.copy(deep=True) # создадим копию датафрейма для обработки
df_old_processed.pop('price') # удаляем столбец 'price'
df_old_processed.shape # выведим размерность
# Out:
# (9619, 19)

# %%
df_old_processed = df_old_processed.select_dtypes(include='number') # выберем только числовые столбцы
df_old_processed
# Out:
#               id  year  odometer        lat        long
# 0     7308295377  2020     27442  35.060000  -85.250000
# 1     7316380095  2016     60023  40.821805  -74.061962
# 2     7313733749  2017     14048  33.779214  -84.411811
# 3     7308210929  2013    117291  35.715954  -78.655304
# 4     7303797340  2012     80465  35.970000  -83.940000
# ...          ...   ...       ...        ...         ...
# 9614  7304876387  2002    150000  42.123900  -79.189500
# 9615  7316152972  2008    113573  43.216990  -77.755610
# 9616  7310993818  2011    150184  44.925908 -122.982753
# 9617  7306637427  2015     61943  43.029559  -89.397796
# 9618  7311960763  2017     35921  36.670000  -76.300000
#
# [9619 rows x 5 columns]

# %%
# добавляем столбец price_category так как это целевая переменная
df_old_processed = df_old_processed.join(df_old.price_category)

# %%
# выведим размерность
df_old_processed.shape
# Out:
# (9619, 6)

# %%
# готовим выборки для обучения
x = df_old_processed.drop(['price_category'], axis=1) # х - не содержит категорию
y = df_old_processed['price_category'] # у - только категория
# создаем выборки для обучения и для тестирования
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# проводим обучение ДЕРЕВО РЕШЕНИЙ
clf = DecisionTreeClassifier(random_state=42)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# находим predict (предсказание) для  x_train, x_test 
predicted_train = clf.predict(x_train)
predicted_test = clf.predict(x_test)

# %%
# выведим метрику модели ДЕРЕВО РЕШЕНИЙ
print(accuracy_score(y_train, predicted_train))
print(accuracy_score(y_test, predicted_test))
# Out:
# 1.0
# 0.545045045045045

# %% [markdown]
# 0.54 - низкая точность модели ДЕРЕВО РЕШЕНИЙ

# %%
# находим три фичи, которые лучшим образом повлияли на предсказательную способность модели.
f_imp_list.sort(key = lambda x: x[1], reverse=True)
f_imp_list[0:3]
# Out:
# [('year', 0.2598828655879754),
#  ('odometer', 0.2464977388786056),
#  ('long', 0.1694801487534133)]

# %%
# проводим обучение СЛУЧАЙНЫЙ ЛЕС
# создаем отдельную переменную rf_clf для классификатора случайного леса
rf_clf = RandomForestClassifier(random_state=42)
# обучим эту переменную
rf_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# выведем предсказанные моделью в predicted_train_rf и predicted_test_rf
predicted_train_rf = rf_clf.predict(x_train)
predicted_test_rf = rf_clf.predict(x_test)
# посчитаем доли правильно предугаданных значений
print(accuracy_score(y_train, predicted_train_rf))
print(accuracy_score(y_test, predicted_test_rf))
# Out:
# 1.0
# 0.6337491337491338

# %% [markdown]
# 0.63 - низкая точность модели СЛУЧАЙНЫЙ ЛЕС

# %%
# находим три фичи, которые лучшим образом повлияли на предсказательную способность модели.
f_imp_list.sort(key = lambda x: x[1], reverse=True)
f_imp_list[0:3]
# Out:
# [('year', 0.2598828655879754),
#  ('odometer', 0.2464977388786056),
#  ('long', 0.1694801487534133)]
